# %%
from functions import *
import pandas as pd
import numpy as np
import json

# %% [markdown]
# # Import training data

# %%
df_train = pd.read_json('data/train/TRAIN.json')
# Transform columns to uppercase
df_train.columns = map(str.upper, df_train.columns)
print(df_train.shape)
df_train.head()
# Out:
# (48893, 6)
#                         ID_OFERTA      SUBCATEGORIA  \
# 0  ef5a8ae0a743018628df9bd53893bb    Administración
# 1  47137c06a640348ca4cb7dcbf938b1  Medicina general
# 2  cdfb72672340819a6721db72eee187         Comercial
# 3  5746210e854264aaca9452f4d377a4  Venta al detalle
# 4  8a1bda0c91438bb4133f32e392a1ce  Venta al detalle
#
#                     CATEGORIA  \
# 0  Administración de empresas
# 1             Sanidad y salud
# 2          Comercial y ventas
# 3           Ventas al detalle
# 4           Ventas al detalle
#
#                                PALABRAS_EMPLEO_TEXTO  ID_PUESTO_ESCO  \
# 0  ADMINISTRATIVO INGLES NAVISION EMPRESAS CARACT...            1634
# 1  MEDICO MEDICINA DIAGNOSTICO TRATAMIENTO LICENC...             611
# 2  REPARTIDOR PERSONA CHOFER VENTAS CLIENTES SEGU...            2825
# 3  DEPENDIENTE PROCESOS SELECCION COMERCIAL TIEND...            1984
# 4  DEPENDIENTE PALMERAS SEMANALES ATENCIONES VENT...            1984
#
#    ID_PUESTO_ESCO_ULL
# 0                1634
# 1                 611
# 2                2825
# 3                1984
# 4                1984

# %% [markdown]
# # Create Vector and Vocabulary

# %%
from functions.vocabulary import create_vocabulary, save_vocabulary
from functions.vectorization import create_vectorize_dataframe, save_vectorized_dataframe

# Create vocabulary
vocabulary = create_vocabulary(df_train)
# Save vocabulary
save_vocabulary(vocabulary, 'data/train/vocabulary.json')
# Create vectorized dataframe
df_train_vectorized = create_vectorize_dataframe(df_train, vocabulary)
# Save vectorized dataframe
save_vectorized_dataframe(df_train_vectorized, 'data/train/df_train_vectorized.npy')
# Out:
# /home/fulp/clasificador_ofertas_empleo/clasificador-ofertas-empleo-modelo/.venv/lib64/python3.9/site-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
