# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import time
from nltk.corpus import stopwords
import json
import numpy as np

# %% [markdown]
# # Legacy function

# %%
dictionary_path = "./static/"
stopwords = stopwords.words('spanish')

def f_vector_palabras_json(texto, palabra_generica):
    # importamos las librerías necesarias
    inicio = time.time()
    #Obtenemos las stopwords del idioma del módulo nltk
    #adverbios
    adverbios = ['ahora', 'antes', 'despues', 'tarde', 'luego', 'ayer', 'temprano', 'ya',
             'todavia', 'anteayer', 'aun', 'pronto', 'hoy', 'aqui', 'ahi', 'alli',
             'cerca', 'lejos', 'fuera', 'dentro', 'alrededor', 'aparte', 'encima',
             'debajo', 'delante', 'detras', 'asi', 'bien', 'mal', 'despacio',
             'deprisa', 'como', 'mucho', 'poco', 'muy', 'casi', 'todo', 'nada', 'algo',
             'medio', 'demasiado', 'bastante', 'mas', 'menos', 'ademas', 'incluso',
             'tambien', 'si', 'asimismo', 'no', 'tampoco', 'jamas', 'nunca', 'acaso',
             'quiza', 'quizas', 'tal', 'vez', 'mejor']
    stopwords.extend(adverbios)

    # Obtengo en un dataframe el diccionario de empleo
    with open(dictionary_path + 'diccionario_empleo.json', encoding="latin-1") as f:
        aux_emp = f.read()
    diccionario_empleo = json.loads(aux_emp)

    paso1 = time.time()
    paso2 = time.time()
    diccionario_palabra = {}
    diccionario_masc = {}
    diccionario_fem = {}
    diccionario_masc_p = {}
    diccionario_fem_p = {}
    for i in range(len(diccionario_empleo)):
        if not (isinstance(diccionario_empleo[i]['PALABRA'], float)):
            # quitar caracteres a la izquierda y la derecha (se ha omitido los símbolos + y @)
            tratar = diccionario_empleo[i]['PALABRA'].strip(r"!#$%^&*()[]{};:,./<>?\|`~-'=_·")
            tratar = tratar.strip('"')

            # quitamos el símbolo español ¡¿ºª y corregimos los acentos y letra ñ
            sin_simbolo = tratar.replace("¡", "")
            sin_simbolo = sin_simbolo.replace("»", "")
            sin_simbolo = sin_simbolo.replace("«", "")
            sin_simbolo = sin_simbolo.replace("¿", "")
            sin_simbolo = sin_simbolo.replace("°", "")
            sin_simbolo = sin_simbolo.replace("º", "")
            sin_simbolo = sin_simbolo.replace("ª", "")
            sin_simbolo = sin_simbolo.replace("á", "A")
            sin_simbolo = sin_simbolo.replace("à", "A")
            sin_simbolo = sin_simbolo.replace("À", "A")
            sin_simbolo = sin_simbolo.replace("Á", "A")
            sin_simbolo = sin_simbolo.replace("é", "E")
            sin_simbolo = sin_simbolo.replace("è", "E")
            sin_simbolo = sin_simbolo.replace("È", "E")
            sin_simbolo = sin_simbolo.replace("É", "E")
            sin_simbolo = sin_simbolo.replace("í", "I")
            sin_simbolo = sin_simbolo.replace("ì", "I")
            sin_simbolo = sin_simbolo.replace("Ì", "I")
            sin_simbolo = sin_simbolo.replace("Í", "I")
            sin_simbolo = sin_simbolo.replace("ó", "O")
            sin_simbolo = sin_simbolo.replace("ò", "O")
            sin_simbolo = sin_simbolo.replace("Ò", "O")
            sin_simbolo = sin_simbolo.replace("Ó", "O")
            sin_simbolo = sin_simbolo.replace("ú", "U")
            sin_simbolo = sin_simbolo.replace("ù", "U")
            sin_simbolo = sin_simbolo.replace("Ù", "U")
            sin_simbolo = sin_simbolo.replace("Ú", "U")
            sin_simbolo = sin_simbolo.replace("ñ", "Ñ")

            # corrección de tildes
            sin_simbolo = sin_simbolo.replace("?", "")

            # comprobamos que no sea un número
            es_numero = sin_simbolo.isdigit()

            # guardamos la palabra si no es número y no vacío
            if ((es_numero == False) and (sin_simbolo != '')):
                # sustituimos en el diccionario la palabra tratada
                palabra_final = sin_simbolo

            diccionario_palabra[palabra_final] = i

        # MASCULINO
        if ((not (isinstance(diccionario_empleo[i]['MASCULINO'], float))) & (
                str(diccionario_empleo[i]['MASCULINO']).isdigit() == False)):
            # quitamos el símbolo español ¡¿ºª y corregimos los acentos y letra ñ
            sin_simbolo = str(diccionario_empleo[i]['MASCULINO']).replace("¡", "")
            sin_simbolo = sin_simbolo.replace("»", "")
            sin_simbolo = sin_simbolo.replace("«", "")
            sin_simbolo = sin_simbolo.replace("¿", "")
            sin_simbolo = sin_simbolo.replace("°", "")
            sin_simbolo = sin_simbolo.replace("º", "")
            sin_simbolo = sin_simbolo.replace("ª", "")
            sin_simbolo = sin_simbolo.replace("á", "A")
            sin_simbolo = sin_simbolo.replace("à", "A")
            sin_simbolo = sin_simbolo.replace("À", "A")
            sin_simbolo = sin_simbolo.replace("Á", "A")
            sin_simbolo = sin_simbolo.replace("é", "E")
            sin_simbolo = sin_simbolo.replace("è", "E")
            sin_simbolo = sin_simbolo.replace("È", "E")
            sin_simbolo = sin_simbolo.replace("É", "E")
            sin_simbolo = sin_simbolo.replace("í", "I")
            sin_simbolo = sin_simbolo.replace("ì", "I")
            sin_simbolo = sin_simbolo.replace("Ì", "I")
            sin_simbolo = sin_simbolo.replace("Í", "I")
            sin_simbolo = sin_simbolo.replace("ó", "O")
            sin_simbolo = sin_simbolo.replace("ò", "O")
            sin_simbolo = sin_simbolo.replace("Ò", "O")
            sin_simbolo = sin_simbolo.replace("Ó", "O")
            sin_simbolo = sin_simbolo.replace("ú", "U")
            sin_simbolo = sin_simbolo.replace("ù", "U")
            sin_simbolo = sin_simbolo.replace("Ù", "U")
            sin_simbolo = sin_simbolo.replace("Ú", "U")
            sin_simbolo = sin_simbolo.replace("ñ", "Ñ")

            # comprobamos que no sea un número
            es_numero = sin_simbolo.isdigit()

            # guardamos la palabra si no es número y no vacío
            if ((es_numero == False) and (sin_simbolo != '')):
                # sustituimos en el diccionario la palabra tratada
                masculino_final = sin_simbolo
                diccionario_masc[masculino_final] = i

        # FEMENINO
        if ((not (isinstance(diccionario_empleo[i]['FEMENINO'], float))) & (
                str(diccionario_empleo[i]['FEMENINO']).isdigit() == False)):

            sin_simbolo = str(diccionario_empleo[i]['FEMENINO']).replace("á", "A")
            sin_simbolo = sin_simbolo.replace("á", "A")
            sin_simbolo = sin_simbolo.replace("à", "A")
            sin_simbolo = sin_simbolo.replace("À", "A")
            sin_simbolo = sin_simbolo.replace("Á", "A")
            sin_simbolo = sin_simbolo.replace("é", "E")
            sin_simbolo = sin_simbolo.replace("è", "E")
            sin_simbolo = sin_simbolo.replace("È", "E")
            sin_simbolo = sin_simbolo.replace("É", "E")
            sin_simbolo = sin_simbolo.replace("í", "I")
            sin_simbolo = sin_simbolo.replace("ì", "I")
            sin_simbolo = sin_simbolo.replace("Ì", "I")
            sin_simbolo = sin_simbolo.replace("Í", "I")
            sin_simbolo = sin_simbolo.replace("ó", "O")
            sin_simbolo = sin_simbolo.replace("ò", "O")
            sin_simbolo = sin_simbolo.replace("Ò", "O")
            sin_simbolo = sin_simbolo.replace("Ó", "O")
            sin_simbolo = sin_simbolo.replace("ú", "U")
            sin_simbolo = sin_simbolo.replace("ù", "U")
            sin_simbolo = sin_simbolo.replace("Ù", "U")
            sin_simbolo = sin_simbolo.replace("Ú", "U")
            sin_simbolo = sin_simbolo.replace("ñ", "Ñ")

            # comprobamos que no sea un número
            es_numero = sin_simbolo.isdigit()

            # guardamos la palabra si no es número y no vacío
            if ((es_numero == False) and (sin_simbolo != '')):
                # sustituimos en el diccionario la palabra tratada
                femenino_final = sin_simbolo
                diccionario_fem[femenino_final] = i

        # MASC_PLURAL
        if ((not (isinstance(diccionario_empleo[i]['MASC_PLURAL'], float))) & (
                str(diccionario_empleo[i]['MASC_PLURAL']).isdigit() == False)):

            sin_simbolo = str(diccionario_empleo[i]['MASC_PLURAL']).replace("á", "A")
            sin_simbolo = sin_simbolo.replace("à", "A")
            sin_simbolo = sin_simbolo.replace("À", "A")
            sin_simbolo = sin_simbolo.replace("Á", "A")
            sin_simbolo = sin_simbolo.replace("é", "E")
            sin_simbolo = sin_simbolo.replace("è", "E")
            sin_simbolo = sin_simbolo.replace("È", "E")
            sin_simbolo = sin_simbolo.replace("É", "E")
            sin_simbolo = sin_simbolo.replace("í", "I")
            sin_simbolo = sin_simbolo.replace("ì", "I")
            sin_simbolo = sin_simbolo.replace("Ì", "I")
            sin_simbolo = sin_simbolo.replace("Í", "I")
            sin_simbolo = sin_simbolo.replace("ó", "O")
            sin_simbolo = sin_simbolo.replace("ò", "O")
            sin_simbolo = sin_simbolo.replace("Ò", "O")
            sin_simbolo = sin_simbolo.replace("Ó", "O")
            sin_simbolo = sin_simbolo.replace("ú", "U")
            sin_simbolo = sin_simbolo.replace("ù", "U")
            sin_simbolo = sin_simbolo.replace("Ù", "U")
            sin_simbolo = sin_simbolo.replace("Ú", "U")
            sin_simbolo = sin_simbolo.replace("ñ", "Ñ")

            # comprobamos que no sea un número
            es_numero = sin_simbolo.isdigit()

            # guardamos la palabra si no es número y no vacío
            if ((es_numero == False) and (sin_simbolo != '')):
                # sustituimos en el diccionario la palabra tratada
                masc_plural_final = sin_simbolo
                diccionario_masc_p[masc_plural_final] = i

        # FEM_PLURAL
        if ((not (isinstance(diccionario_empleo[i]['FEM_PLURAL'], float))) & (
                str(diccionario_empleo[i]['FEM_PLURAL']).isdigit() == False)):

            sin_simbolo = str(diccionario_empleo[i]['FEM_PLURAL']).replace("á", "A")
            sin_simbolo = sin_simbolo.replace("à", "A")
            sin_simbolo = sin_simbolo.replace("À", "A")
            sin_simbolo = sin_simbolo.replace("Á", "A")
            sin_simbolo = sin_simbolo.replace("é", "E")
            sin_simbolo = sin_simbolo.replace("è", "E")
            sin_simbolo = sin_simbolo.replace("È", "E")
            sin_simbolo = sin_simbolo.replace("É", "E")
            sin_simbolo = sin_simbolo.replace("í", "I")
            sin_simbolo = sin_simbolo.replace("ì", "I")
            sin_simbolo = sin_simbolo.replace("Ì", "I")
            sin_simbolo = sin_simbolo.replace("Í", "I")
            sin_simbolo = sin_simbolo.replace("ó", "O")
            sin_simbolo = sin_simbolo.replace("ò", "O")
            sin_simbolo = sin_simbolo.replace("Ò", "O")
            sin_simbolo = sin_simbolo.replace("Ó", "O")
            sin_simbolo = sin_simbolo.replace("ú", "U")
            sin_simbolo = sin_simbolo.replace("ù", "U")
            sin_simbolo = sin_simbolo.replace("Ù", "U")
            sin_simbolo = sin_simbolo.replace("Ú", "U")
            sin_simbolo = sin_simbolo.replace("ñ", "Ñ")

            # comprobamos que no sea un número
            es_numero = sin_simbolo.isdigit()

            # guardamos la palabra si no es número y no vacío
            if ((es_numero == False) and (sin_simbolo != '')):
                # sustituimos en el diccionario la palabra tratada
                fem_plural_final = sin_simbolo
                diccionario_fem_p[fem_plural_final] = i

    paso3 = time.time()

    # Obtengo en un dataframe el diccionario de equivalencias
    with open(dictionary_path + 'diccionario_equivalencias.json',
              encoding="latin-1") as f:
        aux_equiv = f.read()
    diccionario_equiv = json.loads(aux_equiv)
    paso4 = time.time()
    diccionario_equiv_p = {}
    for i in range(len(diccionario_equiv)):
        if ((not (isinstance(diccionario_equiv[i]['PALABRA'], float))) & (str(diccionario_equiv[i]['PALABRA']).isdigit() == False)):
            # quitar caracteres a la izquierda y la derecha (se ha omitido los símbolos + y @)
            tratar = diccionario_equiv[i]['PALABRA'].strip(r"!#$%^&*()[]{};:,./<>?\|`~-'=_·")
            tratar = tratar.strip('"')

            # quitamos el símbolo español ¡¿ºª y corregimos los acentos y letra ñ
            sin_simbolo = tratar.replace("¡", "")
            sin_simbolo = sin_simbolo.replace("»", "")
            sin_simbolo = sin_simbolo.replace("«", "")
            sin_simbolo = sin_simbolo.replace("¿", "")
            sin_simbolo = sin_simbolo.replace("°", "")
            sin_simbolo = sin_simbolo.replace("º", "")
            sin_simbolo = sin_simbolo.replace("ª", "")
            sin_simbolo = sin_simbolo.replace("á", "A")
            sin_simbolo = sin_simbolo.replace("à", "A")
            sin_simbolo = sin_simbolo.replace("À", "A")
            sin_simbolo = sin_simbolo.replace("Á", "A")
            sin_simbolo = sin_simbolo.replace("é", "E")
            sin_simbolo = sin_simbolo.replace("è", "E")
            sin_simbolo = sin_simbolo.replace("È", "E")
            sin_simbolo = sin_simbolo.replace("É", "E")
            sin_simbolo = sin_simbolo.replace("í", "I")
            sin_simbolo = sin_simbolo.replace("ì", "I")
            sin_simbolo = sin_simbolo.replace("Ì", "I")
            sin_simbolo = sin_simbolo.replace("Í", "I")
            sin_simbolo = sin_simbolo.replace("ó", "O")
            sin_simbolo = sin_simbolo.replace("ò", "O")
            sin_simbolo = sin_simbolo.replace("Ò", "O")
            sin_simbolo = sin_simbolo.replace("Ó", "O")
            sin_simbolo = sin_simbolo.replace("ú", "U")
            sin_simbolo = sin_simbolo.replace("ù", "U")
            sin_simbolo = sin_simbolo.replace("Ù", "U")
            sin_simbolo = sin_simbolo.replace("Ú", "U")
            sin_simbolo = sin_simbolo.replace("ñ", "Ñ")

            # corrección de tildes
            sin_simbolo = sin_simbolo.replace("?", "")

            # comprobamos que no sea un número
            es_numero = sin_simbolo.isdigit()

            # guardamos la palabra si no es número y no vacío
            if ((es_numero == False) and (sin_simbolo != '')):
                # sustituimos en el diccionario la palabra tratada
                equivalencia_palabra = sin_simbolo
                diccionario_equiv_p[equivalencia_palabra] = i

    paso5 = time.time()

    vector_palabras = list()

    lista_palabras = str(texto).lower()
    palabras = lista_palabras.split()
    filtered_words = [word for word in palabras if word not in stopwords]

    table = {33: 32, 35: 32, 36: 32, 37: 32, 94: 32, 38: 32, 42: 32, 40: 32, 41: 32, 91: 32, 93: 32,
             123: 32, 125: 32, 58: 32, 59: 32, 44: 32, 47: 32, 60: 32, 62: 32, 92: 32, 124: 32, 96: 32,
             126: 32, 45: 32, 34: 32, 39: 32, 61: 32, 95: 32, 43: 32}

    palabras_encontradas = []

    for j in range(len(filtered_words)):
        sin_simbolo = filtered_words[j].replace("¡", "")
        sin_simbolo = sin_simbolo.replace("»", "")
        sin_simbolo = sin_simbolo.replace("«", "")
        sin_simbolo = sin_simbolo.replace("¿", "")
        sin_simbolo = sin_simbolo.replace("°", "")
        sin_simbolo = sin_simbolo.replace("º", "")
        sin_simbolo = sin_simbolo.replace("ª", "")
        sin_simbolo = sin_simbolo.replace("_x000d_", "")
        sin_simbolo = sin_simbolo.replace("@", "o")
        sin_simbolo = sin_simbolo.replace("á", "a")
        sin_simbolo = sin_simbolo.replace("à", "a")
        sin_simbolo = sin_simbolo.replace("À", "a")
        sin_simbolo = sin_simbolo.replace("Á", "a")
        sin_simbolo = sin_simbolo.replace("é", "e")
        sin_simbolo = sin_simbolo.replace("è", "e")
        sin_simbolo = sin_simbolo.replace("È", "e")
        sin_simbolo = sin_simbolo.replace("É", "e")
        sin_simbolo = sin_simbolo.replace("í", "i")
        sin_simbolo = sin_simbolo.replace("ì", "i")
        sin_simbolo = sin_simbolo.replace("Ì", "i")
        sin_simbolo = sin_simbolo.replace("Í", "i")
        sin_simbolo = sin_simbolo.replace("ó", "o")
        sin_simbolo = sin_simbolo.replace("ò", "o")
        sin_simbolo = sin_simbolo.replace("Ò", "o")
        sin_simbolo = sin_simbolo.replace("Ó", "o")
        sin_simbolo = sin_simbolo.replace("ú", "u")
        sin_simbolo = sin_simbolo.replace("ù", "u")
        sin_simbolo = sin_simbolo.replace("Ù", "u")
        sin_simbolo = sin_simbolo.replace("Ú", "u")
        sin_simbolo = sin_simbolo.replace("ñ", "ñ")
        sin_simbolo = sin_simbolo.replace("?", "")
        tratar = sin_simbolo.strip(r"!#$%^&*()[]{};:,./<>?\|`~-'=_·")
        tratar2 = tratar.translate(table)
        palabras = tratar2.split()
        tokens = []
        for palabra in palabras:
            if palabra not in stopwords:
                tokens.append(palabra.upper())
        for w in tokens:
            es_numero = w.isdigit()
            if len(w) > 2 and not es_numero:
                palabras_encontradas.append(w)

    for i in range(len(palabras_encontradas)):
        # Se comprueba PALABRA de DICCIONARIO_EMPLEO
        if palabras_encontradas[i] in diccionario_palabra and diccionario_empleo[diccionario_palabra[palabras_encontradas[i]]]['PALABRA'] not in vector_palabras and (diccionario_empleo[diccionario_palabra[palabras_encontradas[i]]]['PALABRA_GENERICA'] == str(palabra_generica) or str(palabra_generica) == "T"):
            vector_palabras.append(diccionario_empleo[diccionario_palabra[palabras_encontradas[i]]]['PALABRA'])
        # Se comprueba MASCULINO de DICCIONARIO_EMPLEO
        elif palabras_encontradas[i] in diccionario_masc and diccionario_empleo[diccionario_masc[palabras_encontradas[i]]]['PALABRA'] not in vector_palabras and (diccionario_empleo[diccionario_masc[palabras_encontradas[i]]]['PALABRA_GENERICA'] == str(palabra_generica) or str(palabra_generica) == "T"):
            vector_palabras.append(diccionario_empleo[diccionario_masc[palabras_encontradas[i]]]['PALABRA'])
        # Se comprueba FEMENINO de DICCIONARIO_EMPLEO
        elif palabras_encontradas[i] in diccionario_fem and diccionario_empleo[diccionario_fem[palabras_encontradas[i]]]['PALABRA'] not in vector_palabras and (diccionario_empleo[diccionario_fem[palabras_encontradas[i]]]['PALABRA_GENERICA'] == str(palabra_generica) or str(palabra_generica) == "T"):
            vector_palabras.append(diccionario_empleo[diccionario_fem[palabras_encontradas[i]]]['PALABRA'])
        # Se comprueba MASC_PLURAL de DICCIONARIO_EMPLEO
        elif palabras_encontradas[i] in diccionario_masc_p and diccionario_empleo[diccionario_masc_p[palabras_encontradas[i]]]['PALABRA'] not in vector_palabras and (diccionario_empleo[diccionario_masc_p[palabras_encontradas[i]]]['PALABRA_GENERICA'] == str(palabra_generica) or str(palabra_generica) == "T"):
            vector_palabras.append(diccionario_empleo[diccionario_masc_p[palabras_encontradas[i]]]['PALABRA'])
        # Se comprueba FEM_PLURAL de DICCIONARIO_EMPLEO
        elif palabras_encontradas[i] in diccionario_fem_p and diccionario_empleo[diccionario_fem_p[palabras_encontradas[i]]]['PALABRA'] not in vector_palabras and (diccionario_empleo[diccionario_fem_p[palabras_encontradas[i]]]['PALABRA_GENERICA'] == str(palabra_generica) or str(palabra_generica) == "T"):
            vector_palabras.append(diccionario_empleo[diccionario_fem_p[palabras_encontradas[i]]]['PALABRA'])
        # Se comprueba DICCIONARIO_EQUIVALENCIAS
        elif palabras_encontradas[i] in diccionario_equiv_p and diccionario_equiv[diccionario_equiv_p[palabras_encontradas[i]]]['PALABRA_CORRECTA'] not in vector_palabras and (diccionario_empleo[diccionario_equiv_p[palabras_encontradas[i]]]['PALABRA_GENERICA'] == str(palabra_generica) or str(palabra_generica) == "T"):
            vector_palabras.append(diccionario_equiv[diccionario_equiv_p[palabras_encontradas[i]]]['PALABRA_CORRECTA'])
    # print("Paso 1: " + str(paso1 - inicio))
    # print("Paso 2: " + str(paso2 - paso1))
    # print("Paso 3: " + str(paso3 - paso2))
    # print("Paso 4: " + str(paso4 - paso3))
    # print("Paso 5: " + str(paso5 - paso4))
    # print("Paso 6: " + str(time.time() - paso5))
    # print("Tiempo total: " + str(time.time() - inicio))
    return vector_palabras

texto = '''
Oferta de empleo de ingeniero de software con experiencia en desarrollo de aplicaciones web y móviles. Voz sobre protocolo de internet Necesaria experiencia en Python, Java y C++.
'''
palabra_generica = "T"
lista_palabras = f_vector_palabras_json(texto, palabra_generica)
print(lista_palabras)
# Out:
# ['INGENIERA', 'SOFTWARE', 'EXPERIENCIA', 'DESARROLLO', 'APLICACIONES', 'WEB', 'MOVIL', 'VOZ', 'PROTOCOLOS', 'INTERNET', 'PYTHON', 'JAVA']

# %% [markdown]
# # Functions

# %%
import re
from unidecode import unidecode

expections = ["@", r"\."]

def clean_text(text):
    # ! EXCEPCIONES MANUALES!!!
    # Cast exceptions to "a"
    text = re.sub(r'@', 'a', text)
    # Cast from "." to ""
    text = re.sub(r'\.', '', text)
    
    # Trim the text
    text = text.strip()
    # Remove accents using unidecode, excluding 'ñ' and 'Ñ'
    text = ''.join(char if char in ('ñ', 'Ñ') else unidecode(char) for char in text)
    # Delete non-alphanumeric characters
    text = re.sub(r'[^\w\s]', ' ', text)
    # Delete additional spaces with regex
    text = re.sub(r'\s+', ' ', text).upper()
    return text

palabra = "Be creative in organising and booking team socials and parties.\r\n- Come up with interesting ideas for team welfare and staff swag.\r\n- Record \"dev videos\" of the team and project.\r\n\r\nSenior Management Support\r\n- Work closely with the Senior Management Team"
palabra = clean_text(palabra)
print(palabra)
# Out:
# BE CREATIVE IN ORGANISING AND BOOKING TEAM SOCIALS AND PARTIES COME UP WITH INTERESTING IDEAS FOR TEAM WELFARE AND STAFF SWAG RECORD DEV VIDEOS OF THE TEAM AND PROJECT SENIOR MANAGEMENT SUPPORT WORK CLOSELY WITH THE SENIOR MANAGEMENT TEAM

# %% [markdown]
# # Import dictionario empleo

# %%
with open(dictionary_path + 'diccionario_empleo.json', encoding="latin-1") as f:
    aux_emp = f.read()
diccionario_empleo = json.loads(aux_emp)
# Take 10 random items from the list
import random
random_items = random.sample(diccionario_empleo, 10)
# Print the random items
for item in random_items:
    # Do not show the property 'ID_PALABRA' and display the rest of properties
    print(item)
# Out:
# {'ID_PALABRA': '14672', 'PALABRA': 'VVSS', 'MASCULINO': '', 'FEMENINO': '', 'MASC_PLURAL': '', 'FEM_PLURAL': '', 'LEMA': '', 'TIPO_PALABRA': '9', 'PALABRA_VISUAL': 'VVSS', 'PALABRA_GENERICA': 'N'}
# {'ID_PALABRA': '356', 'PALABRA': 'ITV', 'MASCULINO': '', 'FEMENINO': 'ITV', 'MASC_PLURAL': '', 'FEM_PLURAL': 'ITVS', 'LEMA': '', 'TIPO_PALABRA': '9', 'PALABRA_VISUAL': 'ITV', 'PALABRA_GENERICA': 'N'}
# {'ID_PALABRA': '8425', 'PALABRA': '11G', 'MASCULINO': '11G', 'FEMENINO': '', 'MASC_PLURAL': '11GES', 'FEM_PLURAL': '', 'LEMA': '', 'TIPO_PALABRA': '', 'PALABRA_VISUAL': '11G', 'PALABRA_GENERICA': 'S'}
# {'ID_PALABRA': '3365', 'PALABRA': 'INSPECTOR', 'MASCULINO': 'INSPECTOR', 'FEMENINO': 'INSPECTORA', 'MASC_PLURAL': 'INSPECTORES', 'FEM_PLURAL': 'INSPECTORAS', 'LEMA': 'inspector, ra', 'TIPO_PALABRA': '5', 'PALABRA_VISUAL': 'INSPECTOR', 'PALABRA_GENERICA': 'S'}
# {'ID_PALABRA': '5986', 'PALABRA': 'AVES', 'MASCULINO': 'AVE', 'FEMENINO': '', 'MASC_PLURAL': 'AVES', 'FEM_PLURAL': '', 'LEMA': 'ave', 'TIPO_PALABRA': '2', 'PALABRA_VISUAL': 'AV', 'PALABRA_GENERICA': 'S'}
# {'ID_PALABRA': '10748', 'PALABRA': 'IPI', 'MASCULINO': '', 'FEMENINO': '', 'MASC_PLURAL': '', 'FEM_PLURAL': '', 'LEMA': '', 'TIPO_PALABRA': '', 'PALABRA_VISUAL': 'IPI', 'PALABRA_GENERICA': 'N'}
# {'ID_PALABRA': '7530', 'PALABRA': 'HUMANIDADES', 'MASCULINO': '', 'FEMENINO': 'HUMANIDAD', 'MASC_PLURAL': '', 'FEM_PLURAL': 'HUMANIDADES', 'LEMA': 'humanidad ', 'TIPO_PALABRA': '2', 'PALABRA_VISUAL': 'HUMANIDAD', 'PALABRA_GENERICA': 'S'}
# {'ID_PALABRA': '9979', 'PALABRA': 'SUSTITUCIONES', 'MASCULINO': '', 'FEMENINO': 'SUSTITUCIÓN', 'MASC_PLURAL': '', 'FEM_PLURAL': 'SUSTITUCIONES', 'LEMA': '', 'TIPO_PALABRA': '', 'PALABRA_VISUAL': 'SUSTITUCIÓN', 'PALABRA_GENERICA': 'S'}
# {'ID_PALABRA': '35', 'PALABRA': 'ADWORDS', 'MASCULINO': '', 'FEMENINO': '', 'MASC_PLURAL': '', 'FEM_PLURAL': '', 'LEMA': '', 'TIPO_PALABRA': '9', 'PALABRA_VISUAL': 'ADWORDS', 'PALABRA_GENERICA': 'N'}
# {'ID_PALABRA': '3242', 'PALABRA': 'IMPLEMENTAR', 'MASCULINO': '', 'FEMENINO': '', 'MASC_PLURAL': '', 'FEM_PLURAL': '', 'LEMA': 'implementar ', 'TIPO_PALABRA': '6', 'PALABRA_VISUAL': 'IMPLEMENTAR', 'PALABRA_GENERICA': 'S'}

# %% [markdown]
# # Cast dictionario empleo to dataframe

# %%
# Cast the list to a dataframe with two columns LEMA that will be PALABRA and FORMA that will be the rest of properties
new_dict = []
formas = ['MASCULINO', 'FEMENINO', 'MASC_PLURAL', 'FEM_PLURAL', 'PALABRA_VISUAL']
for item in diccionario_empleo:
    for forma in formas:
        if forma in item.keys() and item[forma] != '':
            new_dict.append({'LEMA': item['PALABRA'], 'FORMA': item[forma], 'PROCENDIA': 'empleo'})
# Cast from list of dictionaries to dataframe
df_empleo = pd.DataFrame(new_dict)
print("Before cleaning:" + str(df_empleo.shape))
df_empleo.head(10)
# Save to csv
df_empleo['FORMA'] = df_empleo['FORMA'].apply(clean_text)
df_empleo['LEMA'] = df_empleo['LEMA'].apply(clean_text)
# Remove duplicates
df_empleo = df_empleo.drop_duplicates()
print("After cleaning:" + str(df_empleo.shape))
df_empleo.to_csv(dictionary_path + 'diccionario_empleo.csv', index=False)
# Out:
# Before cleaning:(13321, 3)
# After cleaning:(10556, 3)

# %% [markdown]
# # Import dicionario equivalencias

# %%
with open(dictionary_path + 'diccionario_equivalencias.json', encoding="latin-1") as f:
    aux_emp = f.read()
dicionario_equivalencias = json.loads(aux_emp)
# Take 10 random items from the list
import random
random_items = random.sample(dicionario_equivalencias, 10)
# Print the random items
for item in random_items:
    # Do not show the property 'ID_PALABRA' and display the rest of properties
    item.pop('ID_PALABRA')
    print(item)
# Out:
# {'PALABRA': 'GRAPHIC', 'PALABRA_CORRECTA': 'GRÁFICO', 'FECHA_INSERCION': '', 'PALABRA_NUEVA': 'N', 'ORIGEN_ULTIMO_TRASPASO': '4', 'FECHA_ULTIMO_TRASPASO': '28/01/21 14:34:12,000000', 'METODO_DETECCION': '', 'PERIODO_ANALISIS_INSER': '', 'FUENTE_DATOS_ORIGEN_INSER': ''}
# {'PALABRA': 'INFORMACON', 'PALABRA_CORRECTA': 'INFORMACIÓN', 'FECHA_INSERCION': '04/07/19', 'PALABRA_NUEVA': 'N', 'ORIGEN_ULTIMO_TRASPASO': '', 'FECHA_ULTIMO_TRASPASO': '04/10/19 13:30:20,000000', 'METODO_DETECCION': '', 'PERIODO_ANALISIS_INSER': '', 'FUENTE_DATOS_ORIGEN_INSER': ''}
# {'PALABRA': 'ACCURACY', 'PALABRA_CORRECTA': 'EXACTITUD', 'FECHA_INSERCION': '28/03/20', 'PALABRA_NUEVA': 'N', 'ORIGEN_ULTIMO_TRASPASO': '4', 'FECHA_ULTIMO_TRASPASO': '16/04/20 21:13:53,000000', 'METODO_DETECCION': 'A', 'PERIODO_ANALISIS_INSER': 'ofertas de infojobs clasificadas procesadas tres veces al mes', 'FUENTE_DATOS_ORIGEN_INSER': 'OFERTAS INFOJOBS'}
# {'PALABRA': 'VI?DEOS', 'PALABRA_CORRECTA': 'VIDEO', 'FECHA_INSERCION': '02/01/21', 'PALABRA_NUEVA': 'N', 'ORIGEN_ULTIMO_TRASPASO': '4', 'FECHA_ULTIMO_TRASPASO': '02/02/21 14:48:11,000000', 'METODO_DETECCION': 'A', 'PERIODO_ANALISIS_INSER': 'ofertas de infojobs clasificadas procesadas tres veces al mes', 'FUENTE_DATOS_ORIGEN_INSER': 'OFERTAS INFOJOBS'}
# {'PALABRA': 'TOWER', 'PALABRA_CORRECTA': 'TORRE', 'FECHA_INSERCION': '02/11/20', 'PALABRA_NUEVA': 'N', 'ORIGEN_ULTIMO_TRASPASO': '4', 'FECHA_ULTIMO_TRASPASO': '04/02/21 13:47:21,000000', 'METODO_DETECCION': 'A', 'PERIODO_ANALISIS_INSER': 'ofertas del 2019 publicadas', 'FUENTE_DATOS_ORIGEN_INSER': 'BB. DD. FULP'}
# {'PALABRA': 'C.C.TV', 'PALABRA_CORRECTA': 'CCTV', 'FECHA_INSERCION': '17/11/19', 'PALABRA_NUEVA': 'N', 'ORIGEN_ULTIMO_TRASPASO': '4', 'FECHA_ULTIMO_TRASPASO': '20/12/19 10:51:46,000000', 'METODO_DETECCION': 'A', 'PERIODO_ANALISIS_INSER': 'ofertas de infojobs clasificadas procesadas tres veces al mes', 'FUENTE_DATOS_ORIGEN_INSER': 'OFERTAS INFOJOBS'}
# {'PALABRA': 'CULTURES', 'PALABRA_CORRECTA': 'CULTURAS', 'FECHA_INSERCION': '02/11/19', 'PALABRA_NUEVA': 'N', 'ORIGEN_ULTIMO_TRASPASO': '4', 'FECHA_ULTIMO_TRASPASO': '18/11/19 12:57:03,000000', 'METODO_DETECCION': 'A', 'PERIODO_ANALISIS_INSER': 'ofertas de infojobs clasificadas procesadas tres veces al mes', 'FUENTE_DATOS_ORIGEN_INSER': 'OFERTAS INFOJOBS'}
# {'PALABRA': 'SELECT', 'PALABRA_CORRECTA': 'SELECCIONE', 'FECHA_INSERCION': '28/03/20', 'PALABRA_NUEVA': 'N', 'ORIGEN_ULTIMO_TRASPASO': '4', 'FECHA_ULTIMO_TRASPASO': '16/04/20 10:29:13,000000', 'METODO_DETECCION': 'A', 'PERIODO_ANALISIS_INSER': 'ofertas de infojobs clasificadas procesadas tres veces al mes', 'FUENTE_DATOS_ORIGEN_INSER': 'OFERTAS INFOJOBS'}
# {'PALABRA': 'CHEMICAL', 'PALABRA_CORRECTA': 'QUIMICA', 'FECHA_INSERCION': '28/03/20', 'PALABRA_NUEVA': 'N', 'ORIGEN_ULTIMO_TRASPASO': '4', 'FECHA_ULTIMO_TRASPASO': '02/04/20 13:15:56,000000', 'METODO_DETECCION': 'A', 'PERIODO_ANALISIS_INSER': 'ofertas de infojobs clasificadas procesadas tres veces al mes', 'FUENTE_DATOS_ORIGEN_INSER': 'OFERTAS INFOJOBS'}
# {'PALABRA': 'TOURISTIC', 'PALABRA_CORRECTA': 'TURISTICA', 'FECHA_INSERCION': '15/10/19', 'PALABRA_NUEVA': 'N', 'ORIGEN_ULTIMO_TRASPASO': '4', 'FECHA_ULTIMO_TRASPASO': '05/11/19 10:30:37,000000', 'METODO_DETECCION': 'A', 'PERIODO_ANALISIS_INSER': 'ofertas de infojobs clasificadas procesadas tres veces al mes', 'FUENTE_DATOS_ORIGEN_INSER': 'OFERTAS INFOJOBS'}

# %% [markdown]
# # Cast dicionario equivalencias to dataframe

# %%
# Cast the list to a dataframe with two columns LEMA that will be PALABRA and FORMA that will be the rest of properties
new_dict = []
formas = ['PALABRA']
for item in dicionario_equivalencias:
    for forma in formas:
        if forma in item.keys() and item[forma] is not '':
            new_dict.append({'LEMA': item['PALABRA_CORRECTA'], 'FORMA': item[forma], 'PROCENDIA': 'equivalencias'})
# Cast from list of dictionaries to dataframe
df_equivalencias = pd.DataFrame(new_dict)
print("Before cleaning:" + str(df_equivalencias.shape))
# Show 10 random samples from the dataframe
print(df_equivalencias.iloc[np.random.randint(0, len(df_equivalencias), 10)])
# Save to csv
df_equivalencias['FORMA'] = df_equivalencias['FORMA'].apply(clean_text)
df_equivalencias['LEMA'] = df_equivalencias['LEMA'].apply(clean_text)
# Remove duplicates
df_equivalencias = df_equivalencias.drop_duplicates()
print("After cleaning:" + str(df_equivalencias.shape))
df_equivalencias.to_csv(dictionary_path + 'diccionario_equivalencias.csv', index=False)
# Out:
# Before cleaning:(2225, 3)
#              LEMA       FORMA      PROCENDIA
# 1121       LENGUA       LENGA  equivalencias
# 1450       PYTHON      PHYTON  equivalencias
# 138      ANUNCIOS   ANNOUNCES  equivalencias
# 1936     SOUVENIR     SUVENIR  equivalencias
# 685    ENFERMERÍA   ENFEMERÍA  equivalencias
# 841   COMBUSTIBLE        FUEL  equivalencias
# 403     CONCURSOS    CONCUROS  equivalencias
# 1485   POSTGRESQL   POSGRESQL  equivalencias
# 306    CARDIÓLOGO  CARDILOGOS  equivalencias
# 1731      R.R.H.H       RR.HH  equivalencias
# After cleaning:(2213, 3)
# <>:6: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:6: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /tmp/ipykernel_406052/2144671456.py:6: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if forma in item.keys() and item[forma] is not '':

# %% [markdown]
# # Modified function

# %%
def get_words_by_text(text, df_empleo, df_equivalencias):
    # Clean the text
    text = clean_text(text)
    # Split the text by " "
    list_words = text.split(" ")
    # Delete empty strings
    list_words = list(filter(None, list_words))
    # Delete stopwords
    list_words = [word for word in list_words if word not in stopwords]
    final_words = []
    for word in list_words:
        # Find the word in the dataframe FORMA column and return the LEMA column the first match
        lema_empleo = df_empleo[df_empleo['FORMA'] == word]['LEMA'].values
        if len(lema_empleo) > 0:
            final_words.append(lema_empleo[0])
        lema_equivalencias = df_equivalencias[df_equivalencias['FORMA'] == word]['LEMA'].values
        if len(lema_equivalencias) > 0:
            final_words.append(lema_equivalencias[0])
    return final_words
    
    
    
texto = '''
Be creative in organising and booking team socials and parties.\r\n- Come up with interesting ideas for team welfare and staff swag.\r\n- Record "dev videos" of the team and project.\r\n\r\nSenior Management Support\r\n- Work closely with the Senior Management Team
'''
list_words = get_words_by_text(texto, df_empleo, df_equivalencias)
print(list_words)
# Out:
# ['RESERVA', 'PROJECTS', 'GESTION', 'SOPORTE', 'GESTION']

# %% [markdown]
# # Import offers

# %%
# Read the offers file 'TRAIN_2021_2023_INFOJOBS.json' as dataframe
df_offers = pd.read_json('./data/descripcion_ofertas_infojobs_21_23.json')
# Show the shape of the dataframe
print(df_offers.shape)
df_offers.head()
# Out:
# (50298, 1)
#                                   descripcion_oferta
# 0  Empresa de carácter internacional solicita adm...
# 1  Las funciones a desempeñar son las propias del...
# 2  Buscamos persona para puesto de Chófer -Repart...
# 3  Abrimos proceso de selección para dependiente ...
# 4  Tus funciones principales serán:\n\n- Atención...

# %% [markdown]
# # Cast offers dataframe to list of descriptions

# %%
# Get a list of 10 random samples from the dataframe in the column 'descripcion_oferta'
offers = df_offers['descripcion_oferta'].sample(100)
print(offers)

results = []

for offer in offers:
    # Get the list of words by text
    list_words_legacy = f_vector_palabras_json(offer, "T")
    list_words_new = get_words_by_text(offer, df_empleo, df_equivalencias)
    # Delete duplicates in list_words_new
    list_words_new = list(dict.fromkeys(list_words_new))
    missing_words_legacy_new = set(list_words_legacy) - set(list_words_new)
    missing_words_new_legacy = set(list_words_new) - set(list_words_legacy)
    results.append({'offer': offer, 'list_words_legacy': list_words_legacy, 'missing_words_legacy_new': list(missing_words_legacy_new), 'list_words_new': list_words_new, 'missing_words_new_legacy': list(missing_words_new_legacy)})
    
# Cast to dataframe
df_results = pd.DataFrame(results)
# Save CSV file
df_results.to_csv(dictionary_path + 'results.csv', index=False)
# Out:
# 15073    Con más de 20 años de experiencia en la presta...
# 8048     Se requiere técnica de estética con experienci...
# 27184    TECNOCASA GROUP\r\n\r\nEmpresa líder en interm...
# 38638    Descripción de la empresa:  \nDesde nuestras m...
# 35868    Grupo Calzedonia es una importante empresa int...
#                                ...
# 7720     Santalucía seguros selecciona personas intuiti...
# 17075    Buscamos ayudantes de camarero que asistan a l...
# 30072    Agencias Exclusivas de Santalucía Seguros sele...
# 18438    La persona seleccionada tendrá como responsabi...
# 21567    ¿Eres AUXILIAR DE ENFERMERÍA o GEROCULTOR /A y...
# Name: descripcion_oferta, Length: 100, dtype: object

# %% [markdown]
# # Show results

# %%
for result in results[:10]:
    print("OFFER:\n" + result['offer'])
    print("LEGACY:\n" + str(result['list_words_legacy']))
    print("NEW:\n" + str(result['list_words_new']))
    # Print the amount of missing words
    print("AMOUNT OF MISSING WORDS IN NEW:\n" + str(len(set(result['list_words_legacy']) - set(result['list_words_new']))))
    # Now print the words in legacy that are not in new
    print("MISSING WORDS IN NEW:\n" + str(set(result['list_words_legacy']) - set(result['list_words_new'])))
# Out:
# OFFER:
# Eurofirms ETT selecciona para importante empresa del sector de Industria Cárnica situada en los alrededores de Las Palmas para días de refuerzo, necesitamos incorporar Carniceros (H/M) para realizar las siguientes funciones:
#
# - Acondicionamiento de materias primas.
# - Despiece en canal de la materia prima.
# - Fileteado, troceado, picado y deshuese del producto cárnico.
# - Clasificación y organización de las piezas, despojos y los restos, siguiendo los criterios establecidos, para su posterior almacenamiento.
# - Manejo de cuchillo, sierra sin fin y maquinaria de producción cárnica.
# - Experiencia en Producción en línea
# LEGACY:
# ['ETT', 'EMPRESAS', 'SECTOR', 'INDUSTRIAS', 'CARNICO', 'ACONDICIONAMIENTO', 'DESPIECE', 'PRODUCTOS', 'CLASIFICACION', 'ORGANIZACIONES', 'ALMACENAMIENTO', 'MAQUINARIA', 'PRODUCCIONES', 'EXPERIENCIA']
# NEW:
# ['ETT', 'EMPRESAS', 'SECTOR', 'INDUSTRIAS', 'CARNICO', 'ACONDICIONAMIENTO', 'DESPIECE', 'PRODUCTOS', 'CLASIFICACION', 'ORGANIZACIONES', 'ALMACENAMIENTO', 'MAQUINARIA', 'PRODUCCIONES', 'EXPERIENCIA']
# AMOUNT OF MISSING WORDS IN NEW:
# 0
# MISSING WORDS IN NEW:
# set()
# OFFER:
# ¿Te gustaría trabajar como Vendedor / Promotor para un fabricante líder en telefonía en plena expansión?
#
# Si tienes disponibilidad de incorporación inmediata, tienes experiencia y ganas de trabajar en el sector de telecomunicaciones ¡queremos conocerte!
#
# Te formaremos y ayudaremos para que disfrutes del trabajo y consigas una estabilidad dentro de la compañía, para que así puedas seguir creciendo con nosotros.
#
# Descripción de la oferta:
# - Atención al cliente y detección de sus necesidades.
# - Asesoramiento al cliente sobre las características técnicas del producto.
# - Venta del producto.
# - Mantenimiento y gestión de la marca en el Centro.
# - Elaboración de reporte de ventas.
#
# Si te apasiona el sector tecnológico, concretamente en mundo de los Smartphone y vives en Santa Cruz de Tenerife, no dudes en inscribirte en la oferta. ¡Únete al equipo!
#
# Se ofrece
# - Contrato laboral RGSS
# - Salario fijo + variable en función de consecución de objetivos.
# - Posibilidad de Desarrollo y crecimiento profesional.
# - Incorporación a grupo empresarial en fase de gran expansión.
# - Estabilidad laboral.
# - Banda salarial: Jornada 40H: 1200? Bruto/mes fijo + variable
# LEGACY:
# ['VENDEDOR', 'PROMOTOR', 'FABRICANTE', 'TELEFONIA', 'EXPERIENCIA', 'SECTOR', 'TELECOMUNICACIONES', 'TRABAJO', 'DESCRIPCION', 'ATENCIONES', 'CLIENTES', 'DETECCION', 'ASESORAMIENTO', 'TECNICO', 'PRODUCTOS', 'VENTAS', 'MANTENIMIENTO', 'GESTION', 'MARCAS', 'CENTRO', 'ELABORACION', 'REPORTES', 'TECNOLOGICA', 'SMARTPHONES', 'EQUIPOS', 'CONTRATOS', 'LABORAL', 'SALARIOS', 'DESARROLLO', 'EMPRESARIAL', 'SALARIAL']
# NEW:
# ['VENDEDOR', 'PROMOTOR', 'FABRICANTE', 'LIDER', 'TELEFONIA', 'EXPERIENCIA', 'SECTOR', 'TELECOMUNICACIONES', 'TRABAJO', 'DESCRIPCION', 'ATENCIONES', 'CLIENTES', 'DETECCION', 'ASESORAMIENTO', 'TECNICO', 'PRODUCTOS', 'VENTAS', 'MANTENIMIENTO', 'GESTION', 'MARCAS', 'CENTRO', 'ELABORACION', 'REPORTES', 'TECNOLOGICA', 'SMARTPHONES', 'EQUIPOS', 'CONTRATOS', 'LABORAL', 'SALARIOS', 'DESARROLLO', 'EMPRESARIAL', 'SALARIAL']
# AMOUNT OF MISSING WORDS IN NEW:
# 0
# MISSING WORDS IN NEW:
# set()
# OFFER:
# ¿Quieres representar a una de las principales marcas de PAE en España?
#
# Stunt Group, empresa de externalización de servicios, buscamos a un promotor/a para trabajar en la tienda de Media Markt Telde para desarrollar la venta de productos de pequeño electrodoméstico.
#
# Tus funciones consistirán en la atención a clientes potenciales, prescripción de productos, demostración y venta en la tienda propia de nuestro cliente.
#
# Las condiciones son las siguientes:
# - Incorporación: Finales de Junio 2023
# - Duración: Campaña estable en el tiempo, puesto fijo
# - Jornada semanal: 16h/s en horario de L y V: 17:00 - 21:00; S: 12:00 - 21:00 (1 hora para comer)
# - Salario: 8.50 ? brutos/hora + incentivos del 15% trimestrales sobre salario según resultados (ventas y visitas Mystery Shopper)
# - Formación: A cargo de la empresa
# - Contrato: Indefinido
# LEGACY:
# ['MARCAS', 'EMPRESAS', 'SERVICIOS', 'PROMOTOR', 'TIENDAS', 'VENTAS', 'PRODUCTOS', 'ELECTRODOMESTICOS', 'ATENCIONES', 'CLIENTES', 'CONDICIONES', 'CAMPAÑA', 'TIEMPO', 'SALARIOS', 'INCENTIVO', 'RESULTADOS', 'VISITAS', 'MYSTERY', 'SHOPPER', 'FORMACIONES', 'CONTRATOS']
# NEW:
# ['MARCAS', 'EMPRESAS', 'SERVICIOS', 'PROMOTOR', 'TIENDAS', 'VENTAS', 'PRODUCTOS', 'ELECTRODOMESTICOS', 'ATENCIONES', 'CLIENTES', 'POTENCIAL', 'CONDICIONES', 'CAMPAÑA', 'TIEMPO', 'SALARIOS', 'INCENTIVO', 'RESULTADOS', 'VISITAS', 'MYSTERY', 'SHOPPER', 'FORMACIONES', 'CONTRATOS']
# AMOUNT OF MISSING WORDS IN NEW:
# 0
# MISSING WORDS IN NEW:
# set()
# OFFER:
# Funciones
# Buscamos un administrativo/a para RR.HH, concretamente, para el área Administración de Personal y/o Dpto. de Selección.
#
# El puesto vacante en Adm personal  consiste en apoyar en la gestión de los diferentes procesos del área (Gestión incorporaciones, vencimientos....) y el puesto en Selección consiste en apoyar en los procesos de selección abiertos y futuros.
#
# Se ofrece
# - Contrato a Jornada Completa.
# - Tipo de Contrato: Indefinido
# LEGACY:
# ['ADMINISTRATIVO', 'R.R.H.H', 'ADMINISTRACION', 'PERSONAL', 'SELECCION', 'GESTION', 'PROCESOS', 'VENCIMIENTOS', 'CONTRATOS']
# NEW:
# ['ADMINISTRATIVO', 'RRHH', 'ADMINISTRACION', 'PERSONAL', 'SELECCION', 'GESTION', 'PROCESOS', 'VENCIMIENTOS', 'CONTRATOS']
# AMOUNT OF MISSING WORDS IN NEW:
# 1
# MISSING WORDS IN NEW:
# {'R.R.H.H'}
# OFFER:
# En el Grupo 1844 buscamos conductores/as que quieran formar parte de nuestro equipo en GC, TFE, LNZ., FTV
#
# Incorporación inmediata. No se precisa experiencia.
#
# Imprescindible persona con residencia en la isla a trabajar.
#
# Tus tareas y responsabilidades principales serán:
#
# -Atención y trato adecuado con los pasajeros.
# -Capacidad de control de las situaciones de estrés.
# -Ser una persona organizada, responsable y puntual.
# -Iniciativa para aprender.
# -Conocer las normas y rutas de circulación.
# Capacidad para lidiar con las emergencias
# Gestión de plataforma interna: documentación del vehículo, partes de seguro, servicios, etc
# .
#
# REQUISITOS:
#
# -Carnet de conducir: D
# -Curso de CAP actualizado.
# -Curso de TACÓGRAFO.
# -Certificado de puntos.
# -Manejo básico digital: mail, plataforma interna de gestión, etc
# -Habilidades para uso del GPS y localización de lugares.
# -Certificado de antecedentes sexuales para poder trabajar con menores
#
# OFRECEMOS:
#
# -Posibilidad de desarrollo profesional: cursos de formación especializada: inglés, atención al cliente, nuevas tecnologías, gestión de flotas, etc...
# -Jornada completa con dos días consecutivos de libranza entre semana.
#
# Las personas que concurran a los procesos de selección y evaluación serán valoradas en base a los requisitos del puesto de trabajo con objetividad, transparencia y respetando el principio de igualdad de oportunidades entre mujeres y hombres.
# LEGACY:
# ['CONDUCTOR', 'EQUIPOS', 'EXPERIENCIA', 'PERSONA', 'RESIDENCIA', 'RESPONSABILIDADES', 'ATENCIONES', 'CAPACIDAD', 'CONTROL', 'ESTRES', 'RESPONSABLE', 'NORMAS', 'CIRCULACION', 'EMERGENCIAS', 'GESTION', 'PLATAFORMAS', 'DOCUMENTACION', 'VEHICULO', 'SEGUROS', 'SERVICIOS', 'CAP', 'TACOGRAFOS', 'CERTIFICADA', 'PUNTOS', 'DIGITAL', 'MAIL', 'SEXUAL', 'DESARROLLO', 'FORMACIONES', 'INGLES', 'CLIENTES', 'TECNOLOGIAS', 'PROCESOS', 'SELECCION', 'EVALUACIONES', 'TRABAJO', 'IGUALDAD']
# NEW:
# ['CONDUCTOR', 'EQUIPOS', 'EXPERIENCIA', 'PERSONA', 'RESIDENCIA', 'RESPONSABILIDADES', 'ATENCIONES', 'CAPACIDAD', 'CONTROL', 'ESTRES', 'RESPONSABLE', 'NORMAS', 'CIRCULACION', 'EMERGENCIAS', 'GESTION', 'PLATAFORMAS', 'DOCUMENTACION', 'VEHICULO', 'SEGUROS', 'SERVICIOS', 'CAP', 'TACOGRAFOS', 'CERTIFICADA', 'PUNTOS', 'DIGITAL', 'MAIL', 'SEXUAL', 'DESARROLLO', 'FORMACIONES', 'INGLES', 'CLIENTES', 'TECNOLOGIAS', 'PROCESOS', 'SELECCION', 'EVALUACIONES', 'TRABAJO', 'IGUALDAD']
# AMOUNT OF MISSING WORDS IN NEW:
# 0
# MISSING WORDS IN NEW:
# set()
# OFFER:
# Funciones
# GESGRUP OUTSOURCING, empresa referente a nivel global en procesos de reclutamiento y selección de personal, precisa de personal de limpieza para desbloqueo de HOTEL en obras en LAS PALMAS DE GRAN CANARIA. Pendiente confirmar la duración del servicio, pero aproximadamente de 1-2 meses.
#
# HORARIO: 8 A 16 HORAS
#
#
#
# Se ofrece
# Oportunidad laboral
# LEGACY:
# ['OUTSOURCING', 'EMPRESAS', 'PROCESOS', 'RECLUTAMIENTO', 'SELECCION', 'PERSONAL', 'LIMPIEZA', 'HOTELES', 'SERVICIOS', 'LABORAL']
# NEW:
# ['OUTSOURCING', 'EMPRESAS', 'PROCESOS', 'RECLUTAMIENTO', 'SELECCION', 'PERSONAL', 'LIMPIEZA', 'HOTELES', 'SERVICIOS', 'LABORAL']
# AMOUNT OF MISSING WORDS IN NEW:
# 0
# MISSING WORDS IN NEW:
# set()
# OFFER:
# Funciones
# - Identificar y evaluar las necesidades sanitarias de los alumnos del centro escolar
# - Administrar tratamientos y medicaciones que han sido prescritos previamente por médicos.
# - Dar cobertura en cualquier emergencia e incidencia que se pueden dar entre los niños en el entorno escolar.
# - Actuar bajo los protocolos estipulados por la medicina
# - Realizar un control y un seguimiento de aquellos alumnos que sufren enfermedades agudas o crónicas
# - Controlar las normas de higiene
# - Hacer registros y monitoreos de los problemas de salud
# - Proporcionar medicamentos y tratamientos médicos
# - Función de educación de la salud
#
# Se ofrece
# - Contrato de sustitución por baja de maternidad.
# - Jornada completa.
# - Salario competitivo
# - Beneficios sociales
# LEGACY:
# ['SANITARIO', 'ALUMNA', 'CENTRO', 'ESCOLAR', 'ADMINISTRAR', 'TRATAMIENTO', 'MEDICACION', 'MEDICO', 'EMERGENCIAS', 'INCIDENCIAS', 'PROTOCOLOS', 'MEDICINA', 'CONTROL', 'SEGUIMIENTOS', 'ENFERMEDADES', 'CRONICA', 'NORMAS', 'HIGIENE', 'REGISTRO', 'MONITOREO', 'SALUD', 'MEDICAMENTOS', 'EDUCACION', 'CONTRATOS', 'SUSTITUCIONES', 'MATERNIDADES', 'SALARIOS', 'BENEFICIOS']
# NEW:
# ['SANITARIO', 'ALUMNA', 'CENTRO', 'ESCOLAR', 'ADMINISTRAR', 'TRATAMIENTO', 'MEDICACION', 'MEDICO', 'EMERGENCIAS', 'INCIDENCIAS', 'PROTOCOLOS', 'MEDICINA', 'CONTROL', 'SEGUIMIENTOS', 'ENFERMEDADES', 'CRONICA', 'NORMAS', 'HIGIENE', 'REGISTRO', 'MONITOREO', 'SALUD', 'MEDICAMENTOS', 'EDUCACION', 'CONTRATOS', 'SUSTITUCIONES', 'MATERNIDADES', 'SALARIOS', 'BENEFICIOS']
# AMOUNT OF MISSING WORDS IN NEW:
# 0
# MISSING WORDS IN NEW:
# set()
# OFFER:
# Se busca personal administrativo de oficina para la gestión de clientes internacionales (customer services) en el turno de tarde (de 14:00 a 22:00)
# - Conocimientos de inglés avanzado imprescindible (hablado y escrito)
# - Manejo Microsoft Dynamics Navision / Business Central
# - Manejo del paquete office
# LEGACY:
# ['PERSONAL', 'ADMINISTRATIVO', 'GESTION', 'CLIENTES', 'INTERNACIONAL', 'INGLES', 'ESCRITO', 'MICROSOFT', 'DYNAMICS', 'NAVISION', 'OFFICE']
# NEW:
# ['PERSONAL', 'ADMINISTRATIVO', 'GESTION', 'CLIENTES', 'INTERNACIONAL', 'INGLES', 'ESCRITO', 'MICROSOFT', 'DYNAMICS', 'NAVISION', 'OFFICE']
# AMOUNT OF MISSING WORDS IN NEW:
# 0
# MISSING WORDS IN NEW:
# set()
# OFFER:
# El Grupo DinoSol, empresa líder en distribución de alimentación y primer empleador canario, cuenta con más de 225 establecimientos y ofrece más de 7.500 empleos directos.
# Desde el área de Recursos Humanos, nos esforzamos por mejorar y llegar a la excelencia cada día, apoyando el desarrollo y crecimiento de las personas. Nuestra prioridad es, sin duda, garantizar el bienestar de nuestros equipos.
#
# Se precisa personal con experiencia en secciones de frutería, panadería, charcutería, carnicería, pescadería, caja y reposición para nuestros centros ubicados en el Sur de Gran Canaria.
# Se requiere: experiencia previa en el puesto, orientación al cliente, orientación a resultados y trabajo en equipo.
#
# Ofrecemos incorporarte a una de las empresas con mayor reconocimiento y proyección de la región que apuesta por el desarrollo y crecimiento del talento, con una alta orientación al cliente y al trabajo en equipo, ¿te unes al reto?.
# LEGACY:
# ['EMPRESAS', 'ALIMENTACION', 'CUENTAS', 'ESTABLECIMIENTOS', 'RECURSOS', 'DESARROLLO', 'PERSONA', 'BIENESTAR', 'EQUIPOS', 'PERSONAL', 'EXPERIENCIA', 'FRUTERIA', 'PANADERIA', 'CHARCUTERIA', 'CARNICERIA', 'PESCADERIA', 'CAJAS', 'REPOSICION', 'CENTROS', 'ORIENTACIONES', 'CLIENTES', 'RESULTADOS', 'TRABAJO', 'RECONOCIMIENTO', 'APUESTAS', 'TALENTO']
# NEW:
# ['EMPRESAS', 'LIDER', 'ALIMENTACION', 'CUENTAS', 'ESTABLECIMIENTOS', 'RECURSOS', 'DESARROLLO', 'PERSONA', 'BIENESTAR', 'EQUIPOS', 'PERSONAL', 'EXPERIENCIA', 'FRUTERIA', 'PANADERIA', 'CHARCUTERIA', 'CARNICERIA', 'PESCADERIA', 'CAJAS', 'REPOSICION', 'CENTRO', 'CENTROS', 'ORIENTACIONES', 'CLIENTES', 'RESULTADOS', 'TRABAJO', 'RECONOCIMIENTO', 'APUESTAS', 'TALENTO']
# AMOUNT OF MISSING WORDS IN NEW:
# 0
# MISSING WORDS IN NEW:
# set()
# OFFER:
# Escojas la historia que escojas, tú eres el protagonista"
#
# En Meliá Hotels International, tienes el poder de crear tu futuro. Para nosotros lo más importante es tu talento: compartimos contigo esa pasión que en el día a día te hace poner tu corazón en todo lo que haces. Estamos a tu lado para ayudarte a ir más allá de tus límites, para celebrar contigo cada victoria. Porque, juntos, protagonizamos nuestras propias historias.
#
# Ubicados en algunos de los puntos de interés turístico más famosos o emergentes del mundo, los resorts de Paradisus by Meliá transportan a sus huéspedes a un paraíso que refleja la belleza natural de su destino. Si tienes espíritu libre y te sientes en armonía con la naturaleza. Disfrutas la vida y buscas experiencias que te ayudan a vivirla en estado puro. Sientes pasión por el lujo y el servicio exquisito sin límites. Sabes crear momentos inolvidables que satisfacen los sentidos en un ambiente de pura libertad. Tu lugar está en Paradisus by Meliá.
#
# Impresionante nuevo resort integrado en un exuberante entorno y situado frente a la playa de San Agustín. Con tu distinguida atención y exquisita arquitectura e interiorismo el cliente se sumergirá en una experiencia de lujo única impregnada por la esencia del destino y la cultura local.&#8239;Este alojamiento en Gran Canaria es un "Destination Inclusive? Luxury Resort", un innovador concepto de todo incluido que ofrece actividades inmersivas de cultura y destino local tanto dentro como fuera del hotel.
#
#  MISIÓN: Ejecutar las escenografías en los montajes para los diferentes espectáculos, eventos y happenings.
#
#
# ¿QUÉ HARAS?
#
# * Asegurar una óptima ejecución de las escenografías en los montajes siguiendo las pautas establecidas.
#
# * Participar en la implementación de nuevos proyectos relacionados con espectáculos, eventos y happenings.
#
# * Asegurarse de que las áreas de trabajo estén en buenas condiciones para su uso y que queden ordenadas después del mismo.
#
# * Controlar el stock del material necesario para realizar la programación, asegurándose del correcto uso según los protocolos y solicitar necesidades de los mismos cuando requerido.
# LEGACY:
# ['HISTORIA', 'HOTELES', 'INTERNACIONAL', 'TALENTO', 'PASION', 'PUNTOS', 'TURISTICA', 'RESORT', 'HUESPEDES', 'BELLEZA', 'NATURAL', 'NATURALEZA', 'LUJO', 'SERVICIOS', 'AMBIENTE', 'ATENCIONES', 'ARQUITECTURA', 'INTERIORISMO', 'CLIENTES', 'EXPERIENCIA', 'UNICA', 'CULTURAS', 'ALOJAMIENTOS', 'INNOVADOR', 'ESCENOGRAFIA', 'MONTAJE', 'ESPECTACULOS', 'EVENTOS', 'ACONTECIMIENTOS', 'EJECUCION', 'PAUTAS', 'IMPLEMENTACION', 'PROYECTO', 'TRABAJO', 'CONDICIONES', 'MATERIAL', 'PROGRAMACIONES', 'PROTOCOLOS']
# NEW:
# ['HISTORIA', 'HOTELES', 'INTERNACIONAL', 'TALENTO', 'PASION', 'PUNTOS', 'TURISTICA', 'RESORT', 'HUESPEDES', 'BELLEZA', 'NATURAL', 'NATURALEZA', 'EXPERIENCIA', 'LUJO', 'SERVICIOS', 'AMBIENTE', 'ATENCIONES', 'ARQUITECTURA', 'INTERIORISMO', 'CLIENTES', 'UNICA', 'CULTURAS', 'ALOJAMIENTOS', 'INNOVADOR', 'ESCENOGRAFIA', 'MONTAJE', 'ESPECTACULOS', 'EVENTOS', 'ACONTECIMIENTOS', 'EJECUCION', 'PAUTAS', 'IMPLEMENTACION', 'PROYECTO', 'TRABAJO', 'CONDICIONES', 'MATERIAL', 'PROGRAMACIONES', 'PROTOCOLOS']
# AMOUNT OF MISSING WORDS IN NEW:
# 0
# MISSING WORDS IN NEW:
# set()
