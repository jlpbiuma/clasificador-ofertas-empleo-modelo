# %%
from functions import *
import pandas as pd
import numpy as np
import json

# %% [markdown]
# # Import training data

# %%
df_train = pd.read_json("./data/offers_matching.json", orient='records', lines=True)
# Transform columns to uppercase
df_train.columns = map(str.upper, df_train.columns)
print(df_train.shape)
df_train.head()
# Out:
# (30283, 23)
#                                                TITLE  \
# 0                                    Abogado Pasante
# 1                       Jefe de estación de servicio
# 2                 Agente Intermediación Inmobiliaria
# 3  Especialista en selección de personal mercado ...
# 4  Agente Comercial | Plan de Carrera (Proceso 2021)
#
#                                          DESCRIPTION  \
# 0  Importante Bufete de Abogados con presencia in...
# 1  Descripción de la oferta\nDuración de la ofert...
# 2  TU MOMENTO ES AHORA, ¡ÚNETE A NOSOTROS Y TE FO...
# 3  KA Resources está buscando hablantes de alemán...
# 4  ¿Reúnes talento comercial y ambición para prog...
#
#                                        COMPANY                    LOCATION  \
# 0  INPORTANTE BUFETE DE ABOGADOS INTERNACIONAL                       Adeje
# 1               Adecco Staffing (Adecco Group)      Santa Cruz de Tenerife
# 2                                   Century 21      Santa Cruz de Tenerife
# 3               KA Resources Recruitment, S.L.   San Bartolomé de Tirajana
# 4                   Seguros Catalana Occidente  Las Palmas de Gran Canaria
#
#              CATEGORY       DATE          SITE          ID  \
# 0             Legales 2021-02-26  infojobs.net  2636589056
# 1          Ingeniería 2021-02-04  infojobs.net  2600512459
# 2  Comercial - Ventas 2021-02-03  infojobs.net  2598070105
# 3    Recursos Humanos 2021-02-27  infojobs.net  2637915491
# 4  Comercial - Ventas 2021-01-16  infojobs.net  2575320427
#
#                                                  URL  \
# 0  https://www.infojobs.net/adeje/abogados-pasant...
# 1  https://www.infojobs.net/santa-cruz-de-tenerif...
# 2  https://www.infojobs.net/santa-cruz-de-tenerif...
# 3  https://www.infojobs.net/san-bartolome-de-tira...
# 4  https://www.infojobs.net/las-palmas-de-gran-ca...
#
#                         ID_OFERTA  ... MAX_NIVEL ID_TITULOS  \
# 0  296dc01a40429b8f2fd0154b9e8f26  ...       NaN       None
# 1  fcdafbdf184295a5db2b6975d8d1b7  ...     125.0     [1743]
# 2  cf09c73f5a4b33af0622cff72e1513  ...      60.0       None
# 3  f61700d6024a55927d91526910d6e9  ...       NaN       None
# 4  3f741ea909423d8100109278a2e139  ...       NaN       None
#
#          TITULOS_RAW                                             ASUNTO  \
# 0               None                    ABOGADOS Y PASANTES CON IDIOMAS
# 1  [Grado en Inglés]     Jefe/a Estación de Servicios - Sur de Tenerife
# 2               None            AGENTE   DE INTERMEDIACION INMOBILIARIA
# 3               None  Especialista en selección de personal mercado ...
# 4               None  Agente Comercial  | Plan de Carrera (Proceso E...
#
#             CATEGORIA                           SUBCATEGORIA  \
# 0               Legal  Derecho civil, penal y constitucional
# 1               Otros                        Sin especificar
# 2  Comercial y ventas                       Agente comercial
# 3    Recursos humanos                  Selección de personal
# 4  Comercial y ventas                       Agente comercial
#
#                                   DESCRIPCION_OFERTA  \
# 0  Importante Bufete de Abogados con presencia in...
# 1  ¿Te apasiona la gestión de equipos, tienes exp...
# 2  TU MOMENTO ES AHORA, ¡ÚNETE A NOSOTROS Y TE FO...
# 3  KA Resources está buscando hablantes de alemán...
# 4  ¿Reúnes talento comercial y ambición para prog...
#
#                                PALABRAS_EMPLEO_TEXTO ID_PUESTO_ESCO_ULL  \
# 0  INTERNACIONAL EXPERIENCIA TRABAJO DERECHOS PRO...                978
# 1  JEFE SERVICIOS GESTION EQUIPOS EXPERIENCIA GER...                317
# 2  AGENTE INTERMEDIACION INMOBILIARIO FORMACIONES...               1607
# 3  ESPECIALISTA SELECCION PERSONAL ALEMAN EQUIPOS...                857
# 4  DIRECTOR PERSONA COMUNICACIONES ESCRITO CAPACI...               1508
#
#   MATCHING
# 0      yes
# 1      yes
# 2      yes
# 3      yes
# 4      yes
#
# [5 rows x 23 columns]

# %% [markdown]
# # Create Vector and Vocabulary

# %%
from functions.vocabulary import create_vocabulary, save_vocabulary, load_vocabulary, filter_vocabulary, get_vocabulary_dimension
from functions.vectorization import create_vectorize_dataframe, save_vectorized_dataframe
# # Load vocabulary
# vocabulary = load_vocabulary('../data/vocabulary/vocabulary_importancia.json')

# def custom_tokenizer_category_subcategory(text):
#     # This function returns the text with underscores instead of spaces
#     text_with_underscores = text.replace(' ', '_')
#     return text_with_underscores

# def setup_vocabulary(vocabulary, df):
#     new_vocabulary = {}
#     new_vocabulary['PALABRAS_EMPLEO_TEXTO'] = [word.lower() for word in vocabulary.keys()]
#     # Get all categories from unique values of CATEGORIA in df
#     new_vocabulary['CATEGORY'] = df['CATEGORY'].apply(custom_tokenizer_category_subcategory).unique().tolist()
#     return new_vocabulary
# # Setup new vocabulary adding CATEGORIA, SUBCATEGORIA, PALABRAS_EMPLEO_TEXTO_NUEVAS
# vocabulary = setup_vocabulary(vocabulary, df_train)
# Create vocabulary
vocabulary = create_vocabulary(df_train)
# Save vocabulary
save_vocabulary(vocabulary, './data/vocabulary.json')
# Create vectorized dataframe
df_train_vectorized = create_vectorize_dataframe(df_train, vocabulary)
# Save vectorized dataframe
save_vectorized_dataframe(df_train_vectorized, './data/df_train_vectorized.npy')
# Out:
# /home/fulp/clasificador_ofertas_empleo/clasificador-ofertas-empleo-modelo/.venv/lib64/python3.9/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /home/fulp/clasificador_ofertas_empleo/clasificador-ofertas-empleo-modelo/.venv/lib64/python3.9/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
print(get_vocabulary_dimension(vocabulary))
# Out:
# 4068
