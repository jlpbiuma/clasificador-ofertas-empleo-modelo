# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functions.signature import *

# %% [markdown]
# # Import RAW data

# %%
df_train_path = '../data/train/TRAIN.json'
df_train = pd.read_json(df_train_path)
# Map columns names to upper
df_train.columns = map(str.upper, df_train.columns)
df_train.head(2)
# Out:
#                         ID_OFERTA      SUBCATEGORIA  \
# 0  ef5a8ae0a743018628df9bd53893bb    Administración
# 1  47137c06a640348ca4cb7dcbf938b1  Medicina general
#
#                     CATEGORIA  \
# 0  Administración de empresas
# 1             Sanidad y salud
#
#                                PALABRAS_EMPLEO_TEXTO  ID_PUESTO_ESCO  \
# 0  ADMINISTRATIVO INGLES NAVISION EMPRESAS CARACT...            1634
# 1  MEDICO MEDICINA DIAGNOSTICO TRATAMIENTO LICENC...             611
#
#    ID_PUESTO_ESCO_ULL
# 0                1634
# 1                 611

# %% [markdown]
# # Visualize type of data

# %%
print('df_train.shape: ', df_train.shape)
print('df_train.columns: ', df_train.columns)
# Out:
# df_train.shape:  (48893, 6)
# df_train.columns:  Index(['ID_OFERTA', 'SUBCATEGORIA', 'CATEGORIA', 'PALABRAS_EMPLEO_TEXTO',
#        'ID_PUESTO_ESCO', 'ID_PUESTO_ESCO_ULL'],
#       dtype='object')

# %% [markdown]
# # Get all the WORDS and COUNT for each Ocupación

# %%
diccionario_ocupacion = create_diccionario_ocupaciones(df_train)
df_train['RELATIVE_SIGNATURE'] = get_offers_signature_relative(df_train, diccionario_ocupacion)
# Out:
# /home/fulp/clasificador_ofertas_empleo/clasificador-ofertas-empleo-modelo/notebooks/functions/signature.py:72: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.247, 0.588, 0.339, 0.2721, 0.5013, 0.4007, 0.3656, 0.5511, 0.2304, 0.6598, 0.5511, 0.6988, 0.4673, 0.6079, 0.3015, 0.6439, 0.3347, 0.2846, 0.5855, 0.5416, 0.6021, 0.7804, 0.5545, 0.1963, 0.6014, 0.4492, 0.4256, 0.5024, 0.5651, 0.5902, 0.2621, 0.1137, 0.423, 0.5392, 0.4913, 0.4896, 0.5276, 0.3674, 0.1978, 0.3841, 0.5159, 0.5002, 0.4621, 0.2224, 0.6867, 0.7009, 0.3667, 0.6452, 0.4101, 0.3942, 0.3117, 0.5342, 0.6631, 0.6621, 0.4948, 0.4604, 0.4879, 0.2862, 0.6506, 0.8899, 0.4122, 0.7306, 0.6506, 0.3942, 0.7222, 0.7477, 0.6461, 0.5863, 0.3729, 0.1975, 0.7647, 0.6455, 0.198, 0.3649, 0.7571, 0.6511, 0.3937, 0.4962, 0.2309, 0.58, 0.1953, 0.3152, 0.2523, 0.5704, 0.3413, 0.6208, 0.4415, 0.5372, 0.3833, 0.352, 0.4908, 0.5704, 0.7385, 0.2974, 0.2346, 0.3972, 0
, 0.6112, 0.5722, 0.3625, 0.361, 0.2167, 0.3256, 0.4094, 0.4865, 0.5224, 0.3226, 0.667, 0.4856, 0.5835, 0.5468, 0.382, 0.4948, 0.349, 0.526, 0.5718, 0.7534, 0.7049, 0.7578, 0.5447, 0.7713, 0.6276, 0.612, 0.6461, 0.7561, 0.4517, 0.6449, 0.338, 0.1039, 0.3521, 0.7106, 0.5315, 0.7578, 0.369, 0.4154, 0.3277, 0.4357, 0.4123, 0.1043, 0.8846, 0.5805, 0.4031, 0.5877, 0.6184, 0.1772, 0.3457, 0.238, 0.6276, 0.3672, 0.7866, 0.6009, 0.4786, 0.4947, 0.4534, 0.4851, 0.4936, 0.4117, 0.6009, 0.5247, 0.5542, 0.6325, 0.3566, 0.3778, 0.352, 0.323, 0.4004, 0.4004, 0.1834, 0.4506, 0.5638, 0.4538, 0.2989, 0.5756, 0.6125, 0.4353, 0.5333, 0.5073, 0.3754, 0.4569, 0.7279, 0.1358, 0.5792, 0.6735, 0.45, 0.5331, 0.635, 0.4666, 0.5201, 0.5605, 0.3347, 0.3135, 0.4933, 0.4017, 0.4864, 0.6293, 0.6068, 0.3041, 0.2965, 0.5707, 0.1806, 0.3295, 0.3598, 0.6828, 0.6234, 0.2032, 0.2787, 0.5956, 0.4614, 0.6973, 1.0, 0.31, 0.5765, 0.4642, 0.208, 0.1787, 0.2107, 0.5342, 0.635, 0.5027, 0.6333, 0.3909, 0.6617, 0.6889, 0.3637, 0.635, 0.2065, 0.5099, 0.2989, 0.2707, 0.6255, 0.163, 0.5577, 0.6255, 0.475, 0.6542, 0.5285, 0.5812, 0.7356, 0.7943, 0.3894, 0.5889, 0.4988, 0.4973, 0.4643, 0.6257, 0.3608, 0.3769, 0.5008, 0.5659, 0.5248, 0.4564, 0.7 ...
#   df.loc[df['ID_PUESTO_ESCO_ULL'] == occupation_id, 'RELATIVE_SIGNATURE'] = signatures

# %%
id_ocupacion = 1607
show_signature_by_occupation(df_train, id_ocupacion)
# Get the mean and the standard deviation
mean = df_train['RELATIVE_SIGNATURE'].mean()
std = df_train['RELATIVE_SIGNATURE'].std()
print('mean: ', mean)
print('std: ', std)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ddd2527a-4d78-4744-bed6-d6bafa86b471">Loading BokehJS ...</span>
#     </div>
#   <div id="d23df676-5754-4746-88c8-878242761535" data-root-id="p1050" style="display: contents;"></div>
# mean:  0.5916719571308776
# std:  0.2216796601223151

# %%
signature_value = 1
lista = get_offers_by_relative_signature_and_occupation(df_train, id_ocupacion, signature_value)
print(lista[0:100])
print(len(lista))
# Out:
# ['704cae292b437f9991d31c8f71328b', '521d1b2d024805826a7ce6fc373b46']
# 2
